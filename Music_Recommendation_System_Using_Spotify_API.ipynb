# %%
#import required libraries to access Spotify’s web API
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyOAuth

#Request access token
import requests
import base64

# Replace with your own Client ID and Client Secret
CLIENT_ID = 'your_client_id'
CLIENT_SECRET = 'your_client_secret'

# Base64 encode the client ID and client secret
client_credentials = f"{CLIENT_ID}:{CLIENT_SECRET}"
client_credentials_base64 = base64.b64encode(client_credentials.encode())

# Request the access token
token_url = 'https://accounts.spotify.com/api/token'
headers = {
    'Authorization': f'Basic {client_credentials_base64.decode()}'
}
data = {
    'grant_type': 'client_credentials'
}
response = requests.post(token_url, data=data, headers=headers)

if response.status_code == 200:
    access_token = response.json()['access_token']
    print("Access token obtained successfully.")
else:
    print("Error obtaining access token.")
    exit()
# Out:
# Access token obtained successfully.

# %%
pip install spotipy --upgrade
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: spotipy in c:\users\user\appdata\roaming\python\python312\site-packages (2.23.0)
# Requirement already satisfied: redis>=3.5.3 in c:\users\user\appdata\roaming\python\python312\site-packages (from spotipy) (5.0.1)
# Requirement already satisfied: requests>=2.25.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from spotipy) (2.31.0)
# Requirement already satisfied: six>=1.15.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from spotipy) (2.0.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\appdata\roaming\python\python312\site-packages (from requests>=2.25.0->spotipy) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\roaming\python\python312\site-packages (from requests>=2.25.0->spotipy) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\roaming\python\python312\site-packages (from requests>=2.25.0->spotipy) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
#collect music data from any playlist on Spotify
def get_trending_playlist_data(playlist_id, access_token):
    # Set up Spotipy with the access token
    sp = spotipy.Spotify(auth=access_token)

    # Get the tracks from the playlist
    playlist_tracks = sp.playlist_tracks(playlist_id, fields='items(track(id, name, artists, album(id, name)))')

    # Extract relevant information and store in a list of dictionaries
    music_data = []
    for track_info in playlist_tracks['items']:
        track = track_info['track']
        track_name = track['name']
        artists = ', '.join([artist['name'] for artist in track['artists']])
        album_name = track['album']['name']
        album_id = track['album']['id']
        track_id = track['id']

        # Get audio features for the track
        audio_features = sp.audio_features(track_id)[0] if track_id != 'Not available' else None

        # Get release date of the album
        try:
            album_info = sp.album(album_id) if album_id != 'Not available' else None
            release_date = album_info['release_date'] if album_info else None
        except:
            release_date = None

        # Get popularity of the track
        try:
            track_info = sp.track(track_id) if track_id != 'Not available' else None
            popularity = track_info['popularity'] if track_info else None
        except:
            popularity = None

        # Add additional track information to the track data
        track_data = {
            'Track Name': track_name,
            'Artists': artists,
            'Album Name': album_name,
            'Album ID': album_id,
            'Track ID': track_id,
            'Popularity': popularity,
            'Release Date': release_date,
            'Duration (ms)': audio_features['duration_ms'] if audio_features else None,
            'Explicit': track_info.get('explicit', None),
            'External URLs': track_info.get('external_urls', {}).get('spotify', None),
            'Danceability': audio_features['danceability'] if audio_features else None,
            'Energy': audio_features['energy'] if audio_features else None,
            'Key': audio_features['key'] if audio_features else None,
            'Loudness': audio_features['loudness'] if audio_features else None,
            'Mode': audio_features['mode'] if audio_features else None,
            'Speechiness': audio_features['speechiness'] if audio_features else None,
            'Acousticness': audio_features['acousticness'] if audio_features else None,
            'Instrumentalness': audio_features['instrumentalness'] if audio_features else None,
            'Liveness': audio_features['liveness'] if audio_features else None,
            'Valence': audio_features['valence'] if audio_features else None,
            'Tempo': audio_features['tempo'] if audio_features else None,
            # Add more attributes as needed
        }

        music_data.append(track_data)

    # Create a pandas DataFrame from the list of dictionaries
    df = pd.DataFrame(music_data)

    return df

# %%
playlist_id = 'your_playlist_id'

# Call the function to get the music data from the playlist and store it in a DataFrame
music_df = get_trending_playlist_data(playlist_id, access_token)

# Display the DataFrame
print(music_df)
# Out:
#                                            Track Name  \
# 0                                             Panadol
# 1                                               Ngozi
# 2                                                FEEL
# 3                                          Terminator
# 4            Soweto (with Don Toliver, Rema & Tempoe)
# 5                                         Don't Leave
# 6                                               Dalie
# 7                                              reason
# 8                                               Water
# 9                                   Party No Dey Stop
# 10                                               YAWA
# 11                                 KANTE (feat. Fave)
# 12                                          City Boys
# 13                                               Mumu
# 14                                         Best Of Me
# 15                                               soso
# 16  BLOOD ON THE DANCE FLOOR (feat. Bloody Civilia...
# 17                                  Lonely At The Top
# 18                          Till We Die (feat. Ruger)
# 19                                            Asiwaju
# 20                                              Charm
# 21                                            Pick Up
# 22                             Overloading (OVERDOSE)
# 23                                            Holiday
# 24                      UNAVAILABLE (feat. Musa Keys)
# 25                                         Sgudi Snyc
# 26                                          Ma Cherie
# 27                                           Amapiano
# 28  Mnike (feat. DJ Maphorisa, Nandipha808, Ceeka ...
# 29                                            Babylon
# 30                                               Rush
# 31                                               Soro
# 32                                             Me & U
# 33                                           Monalisa
# 34                                 Shu! (feat. Chley)
# 35                             Dollar For Love (Baby)
# 36                                              Enjoy
# 37                                         GWAGWALADA
# 38                                          Xtra Cool
# 39                                           Sability
# 40                                            Stamina
# 41                                            Bandana
# 42               People (feat. Ayra Starr & Omah Lay)
# 43                                        It's Plenty
# 44                                         Duffel Bag
# 45                                           Ojapiano
# 46                                           Basquiat
# 47                                              Jinja
# 48                                               Tour
# 49  Peacock Revisit (feat. Ice Beats Slide & Sbuda...
#
#                                               Artists  \
# 0                                             Mr Eazi
# 1                                  Crayon, Ayra Starr
# 2                                              Davido
# 3                                        King Promise
# 4                  Victony, Rema, Tempoe, Don Toliver
# 5                                                Rema
# 6   Kamo Mphela, Tyler ICU, Khalil Harrison, Baby ...
# 7                                            Omah Lay
# 8                                                Tyla
# 9                           Adekunle Gold, Zinoleesky
# 10                                        Fireboy DML
# 11                                       Davido, Fave
# 12                                          Burna Boy
# 13                                 DJ Neptune, Joeboy
# 14                                               Bnxn
# 15                                           Omah Lay
# 16                ODUMODUBLVCK, Bloody Civilian, Wale
# 17                                              Asake
# 18                                    Sarkodie, Ruger
# 19                                              Ruger
# 20                                               Rema
# 21                                        Tiwa Savage
# 22  Mavins, Crayon, Ayra Starr, LADIPOE, Magixx, B...
# 23                                               Rema
# 24                                  Davido, Musa Keys
# 25                  De Mthuda, Da Muziqal Chef, Eemoh
# 26                                               Bien
# 27                                     Asake, Olamide
# 28  Tyler ICU, Tumelo_za, DJ Maphorisa, Nandipha80...
# 29                               Patoranking, Victony
# 30                                         Ayra Starr
# 31                                      Adekunle Gold
# 32                                               Tems
# 33                           Lojay, Sarz, Chris Brown
# 34                            Diamond Platnumz, Chley
# 35                                    Thuto The Human
# 36                              Jux, Diamond Platnumz
# 37                      Bnxn, Kizz Daniel, Seyi Vibez
# 38                                         Young Jonn
# 39                                         Ayra Starr
# 40                Tiwa Savage, Ayra Starr, Young Jonn
# 41                                 Fireboy DML, Asake
# 42                     Libianca, Ayra Starr, Omah Lay
# 31  5bYTh2T6OCVtwnQmwWBUis          63   2023-07-28         162603     False
# 32  4nFrcGM7MY1mpoQCC7Kefj          80   2023-10-05         192936     False
# 33  3baPniPXS0iEII8rDUJdYP          77   2022-05-19         212976     False
# 34  442DDArcRLNRxEeF75jRVk          63   2023-07-03         263571     False
# 35  46906mYFRf4gRPqvdrhWhX          60   2023-09-08         413844     False
# 36  3osydJRsRqgVFKYTC04QfT          64   2023-07-14         216724     False
# 37  6wuMo4ZR83PhlhXhJ1S3VY          70   2023-02-15         190542     False
# 38  5F4OfeowSReF93KcH2eUcG          72   2022-09-23         150000      True
# 39  5V9XFfvCG4WP5ZdISOLvaF          69   2023-02-10         166559     False
# 40  1tOp1bXhT9tvydSAGDHdQy          70   2023-03-14         169043     False
# 41  5CTQCPv51aLWpwTbqo8mEL          66   2022-07-13         178225      True
# 42  4AxG1T6UJJ4xCX4Wz6JDLG          75   2023-03-31         184633      True
# 43  5hVjoL3sHepZROri63wBxP          75   2022-07-07         216992      True
# 44  3d04OfVqip9ZQdvboUsPg3          62   2023-04-07         126906     False
# 45  6WZVnqQ9OZRSGZmXyHHlV3          71   2023-06-03         168421     False
# 46  2H0w7oYDjUvgsFlNQ5swIg          73   2023-06-15         134483     False
# 47  5dVJTSZhL2n81ZkT4PZu0x          69   2023-08-08         155020     False
# 48  1Jj1sgeQ71UoGgetecz7mT          67   2023-09-01         172394      True
# 49  1NQCinyxiglxekxXVPEhnC          68   2023-08-11         326027     False
#
#                                         External URLs  ...  Energy  Key  \
# 0   https://open.spotify.com/track/2VkxvwW5Vb3hWrB...  ...   0.674    0
# 1   https://open.spotify.com/track/5mhM7bfzv52bzfC...  ...   0.428    6
# 2   https://open.spotify.com/track/1mk8ZC9OeTZMr8W...  ...   0.831    2
# 3   https://open.spotify.com/track/1oq33HJBs0rDmjj...  ...   0.638    1
# 4   https://open.spotify.com/track/25Kyv5SeEenT0EE...  ...   0.756    5
# 5   https://open.spotify.com/track/19fCpJYZVtBKyOt...  ...   0.780    1
# 6   https://open.spotify.com/track/7HmE17lcfpENCJk...  ...   0.568    1
# 7   https://open.spotify.com/track/2D0HvqDFPK7YmT7...  ...   0.693    2
# 8   https://open.spotify.com/track/5aIVCx5tnk0ntmd...  ...   0.722    3
# 9   https://open.spotify.com/track/0Em4eY10PGyiBlm...  ...   0.657    5
# 10  https://open.spotify.com/track/5tM3Fo4qBqDAwWJ...  ...   0.609    9
# 11  https://open.spotify.com/track/7vKXc90NT5WBm3U...  ...   0.809    6
# 12  https://open.spotify.com/track/4RoKNqyZ9622tcA...  ...   0.634    2
# 13  https://open.spotify.com/track/05bS6TTT5lXiDfO...  ...   0.857   11
# 14  https://open.spotify.com/track/3Z19t8pNaAHqlLm...  ...   0.642    9
# 15  https://open.spotify.com/track/1wADwLSkYhrSmy4...  ...   0.725    3
# 16  https://open.spotify.com/track/35MU2MEhQMw0NhX...  ...   0.835    1
# 17  https://open.spotify.com/track/5ZtK8XAVnoaGdBX...  ...   0.801    6
# 18  https://open.spotify.com/track/0tdbVxn9Qewgtv2...  ...   0.551    0
# 19  https://open.spotify.com/track/7ErtOGQ9DwyQa3l...  ...   0.600    8
# 20  https://open.spotify.com/track/1iBWjQ9af9NnUd5...  ...   0.663    4
# 21  https://open.spotify.com/track/1deimiQlzca70jz...  ...   0.677    9
# 22  https://open.spotify.com/track/4lVEVXrlQlXPdYW...  ...   0.611    0
# 23  https://open.spotify.com/track/3ceZIRUX8m8qFFc...  ...   0.675    6
# 24  https://open.spotify.com/track/2kaH2Z8ezDUKf6f...  ...   0.649    2
# 25  https://open.spotify.com/track/0XSYoJ0MJpMB2td...  ...   0.399    0
# 26  https://open.spotify.com/track/3PemVHtCIb5abIT...  ...   0.789    0
# 27  https://open.spotify.com/track/3GMdp6clyAh7wZW...  ...   0.651    0
# 28  https://open.spotify.com/track/5tpft20jhQvRlG3...  ...   0.504    1
# 29  https://open.spotify.com/track/0V9hYbo9uL11hqL...  ...   0.606    0
# 30  https://open.spotify.com/track/1rrqJ9QkOBYJlsZ...  ...   0.503    1
# 31  https://open.spotify.com/track/5bYTh2T6OCVtwnQ...  ...   0.637    2
# 32  https://open.spotify.com/track/4nFrcGM7MY1mpoQ...  ...   0.662   10
# 33  https://open.spotify.com/track/3baPniPXS0iEII8...  ...   0.726   10
# 34  https://open.spotify.com/track/442DDArcRLNRxEe...  ...   0.890    1
# 35  https://open.spotify.com/track/46906mYFRf4gRPq...  ...   0.543    7
# 36  https://open.spotify.com/track/3osydJRsRqgVFKY...  ...   0.672    8
# 37  https://open.spotify.com/track/6wuMo4ZR83PhlhX...  ...   0.569    4
# 38  https://open.spotify.com/track/5F4OfeowSReF93K...  ...   0.725    6
# 39  https://open.spotify.com/track/5V9XFfvCG4WP5Zd...  ...   0.700    4
# 40  https://open.spotify.com/track/1tOp1bXhT9tvydS...  ...   0.631    8
# 41  https://open.spotify.com/track/5CTQCPv51aLWpwT...  ...   0.605    1
# 42  https://open.spotify.com/track/4AxG1T6UJJ4xCX4...  ...   0.453   10
# 43  https://open.spotify.com/track/5hVjoL3sHepZROr...  ...   0.565    7
# 44  https://open.spotify.com/track/3d04OfVqip9ZQdv...  ...   0.540    8
# 45  https://open.spotify.com/track/6WZVnqQ9OZRSGZm...  ...   0.795   10
# 46  https://open.spotify.com/track/2H0w7oYDjUvgsFl...  ...   0.767    5
# 47  https://open.spotify.com/track/5dVJTSZhL2n81Zk...  ...   0.735    4
# 48  https://open.spotify.com/track/1Jj1sgeQ71UoGge...  ...   0.680   11
# 49  https://open.spotify.com/track/1NQCinyxiglxekx...  ...   0.443    2
#
#     Loudness  Mode  Speechiness  Acousticness  Instrumentalness  Liveness  \
# 0     -7.600     1       0.0880       0.34200          0.000694    0.3480
# 1    -14.557     1       0.2470       0.03350          0.000006    0.0623
# 2     -6.210     1       0.0800       0.09230          0.176000    0.0819
# 3     -6.549     1       0.0394       0.02590          0.001290    0.0724
# 4     -5.392     0       0.0761       0.05410          0.000000    0.1090
# 5     -5.098     1       0.0667       0.00423          0.000000    0.6190
# 6     -9.984     1       0.0515       0.00005          0.090100    0.1220
# 7     -8.111     1       0.2450       0.37300          0.000234    0.1200
# 8     -3.495     0       0.0755       0.08560          0.000000    0.1370
# 9     -7.779     0       0.1470       0.20400          0.000014    0.0668
# 10    -6.498     1       0.0401       0.08050          0.000416    0.0842
# 31    0.215  109.199
# 32    0.257  112.014
# 33    0.670  113.017
# 34    0.722  112.016
# 35    0.190  112.990
# 36    0.804  115.959
# 37    0.630  113.046
# 38    0.556  120.000
# 39    0.850  119.997
# 40    0.794  108.783
# 41    0.366  104.931
# 42    0.622  123.906
# 43    0.530  107.035
# 44    0.612  139.362
# 45    0.565  114.003
# 46    0.857  115.957
# 47    0.403   95.992
# 48    0.788  142.017
# 49    0.260  111.980
#
# [50 rows x 21 columns]

# %%
print(music_df.isnull().sum())
# Out:
# Track Name          0
# Artists             0
# Album Name          0
# Album ID            0
# Track ID            0
# Popularity          0
# Release Date        0
# Duration (ms)       0
# Explicit            0
# External URLs       0
# Danceability        0
# Energy              0
# Key                 0
# Loudness            0
# Mode                0
# Speechiness         0
# Acousticness        0
# Instrumentalness    0
# Liveness            0
# Valence             0
# Tempo               0
# dtype: int64

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from datetime import datetime
from sklearn.metrics.pairwise import cosine_similarity

data = music_df

# %%
# Function to calculate weighted popularity scores based on release date
def calculate_weighted_popularity(release_date):
    # Convert the release date to datetime object
    release_date = datetime.strptime(release_date, '%Y-%m-%d')

    # Calculate the time span between release date and today's date
    time_span = datetime.now() - release_date

    # Calculate the weighted popularity score based on time span (e.g., more recent releases have higher weight)
    weight = 1 / (time_span.days + 1)
    return weight

# %%
# Normalize the music features using Min-Max scaling
scaler = MinMaxScaler()
music_features = music_df[['Danceability', 'Energy', 'Key',
                           'Loudness', 'Mode', 'Speechiness', 'Acousticness',
                           'Instrumentalness', 'Liveness', 'Valence', 'Tempo']].values
music_features_scaled = scaler.fit_transform(music_features)

# %%
# a function to get content-based recommendations based on music features
def content_based_recommendations(input_song_name, num_recommendations=5):
    if input_song_name not in music_df['Track Name'].values:
        print(f"'{input_song_name}' not found in the dataset. Please enter a valid song name.")
        return

    # Get the index of the input song in the music DataFrame
    input_song_index = music_df[music_df['Track Name'] == input_song_name].index[0]

    # Calculate the similarity scores based on music features (cosine similarity)
    similarity_scores = cosine_similarity([music_features_scaled[input_song_index]], music_features_scaled)

    # Get the indices of the most similar songs
    similar_song_indices = similarity_scores.argsort()[0][::-1][1:num_recommendations + 1]

    # Get the names of the most similar songs based on content-based filtering
    content_based_recommendations = music_df.iloc[similar_song_indices][['Track Name', 'Artists', 'Album Name', 'Release Date', 'Popularity']]

    return content_based_recommendations

# %%
# a function to get hybrid recommendations based on weighted popularity
def hybrid_recommendations(input_song_name, num_recommendations=5, alpha=0.5):
    if input_song_name not in music_df['Track Name'].values:
        print(f"'{input_song_name}' not found in the dataset. Please enter a valid song name.")
        return

    # Get content-based recommendations
    content_based_rec = content_based_recommendations(input_song_name, num_recommendations)

    # Get the popularity score of the input song
    popularity_score = music_df.loc[music_df['Track Name'] == input_song_name, 'Popularity'].values[0]

    # Calculate the weighted popularity score
    weighted_popularity_score = popularity_score * calculate_weighted_popularity(music_df.loc[music_df['Track Name'] == input_song_name, 'Release Date'].values[0])

    # Combine content-based and popularity-based recommendations based on weighted popularity
    hybrid_recommendations = content_based_rec
    # Create a new DataFrame object with the new row included
    hybrid_recommendations = pd.DataFrame({
        'Track Name': [input_song_name],
        'Artists': [music_df.loc[music_df['Track Name'] == input_song_name, 'Artists'].values[0]],
        'Album Name': [music_df.loc[music_df['Track Name'] == input_song_name, 'Album Name'].values[0]],
        'Release Date': [music_df.loc[music_df['Track Name'] == input_song_name, 'Release Date'].values[0]],
        'Popularity': [weighted_popularity_score]
    })

    # Append the new DataFrame to the existing DataFrame
    hybrid_recommendations = pd.concat([hybrid_recommendations, content_based_rec], ignore_index=True)
  

    # Sort the hybrid recommendations based on weighted popularity score
    hybrid_recommendations = hybrid_recommendations.sort_values(by='Popularity', ascending=False)

    # Remove the input song from the recommendations
    hybrid_recommendations = hybrid_recommendations[hybrid_recommendations['Track Name'] != input_song_name]


    return hybrid_recommendations

# %%
input_song_name = "Ma Cherie"
recommendations = hybrid_recommendations(input_song_name, num_recommendations=20)
recommendations = recommendations.reset_index(drop=True)
print(f"Hybrid recommended songs for '{input_song_name}':")
recommendations
# Out:
# Hybrid recommended songs for 'Ma Cherie':
#                                            Track Name  \
# 0                                               Water
# 1                                           City Boys
# 2                                   Lonely At The Top
# 3            Soweto (with Don Toliver, Rema & Tempoe)
# 4                                                soso
# 5                                            Monalisa
# 6                                               Charm
# 7                                                FEEL
# 8                                  KANTE (feat. Fave)
# 9                                          Terminator
# 10                                          Xtra Cool
# 11  BLOOD ON THE DANCE FLOOR (feat. Bloody Civilia...
# 12                                         GWAGWALADA
# 13                                           Amapiano
# 14                                  Party No Dey Stop
# 15                                           Sability
# 16                                              Jinja
# 17                                              Enjoy
# 18                                               Mumu
# 19                                 Shu! (feat. Chley)
#
#                                 Artists  \
# 0                                  Tyla
# 1                             Burna Boy
# 2                                 Asake
# 3    Victony, Rema, Tempoe, Don Toliver
# 4                              Omah Lay
# 5              Lojay, Sarz, Chris Brown
# 6                                  Rema
# 7                                Davido
# 8                          Davido, Fave
# 9                          King Promise
# 10                           Young Jonn
# 11  ODUMODUBLVCK, Bloody Civilian, Wale
# 12        Bnxn, Kizz Daniel, Seyi Vibez
# 13                       Asake, Olamide
# 14            Adekunle Gold, Zinoleesky
# 15                           Ayra Starr
# 16                              Olamide
# 17                Jux, Diamond Platnumz
# 18                   DJ Neptune, Joeboy
# 19              Diamond Platnumz, Chley
#
#                                     Album Name Release Date  Popularity
# 0                                        Water   2023-07-28        94.0
# 1                               I Told Them...   2023-08-24        85.0
# 2                                  Work Of Art   2023-06-15        78.0
# 3   Soweto (with Don Toliver, Rema and Tempoe)   2023-03-22        78.0
# 4                                    Boy Alone   2022-07-14        77.0
# 5                                     Monalisa   2022-05-19        77.0
# 6                           Rave & Roses Ultra   2023-04-27        77.0
# 7                                     Timeless   2023-03-30        74.0
# 8                                     Timeless   2023-03-30        73.0
# 9                                   Terminator   2023-05-05        73.0
# 10                                   Xtra Cool   2022-09-23        72.0
# 11                                     EZIOKWU   2023-10-06        71.0
# 12                                  GWAGWALADA   2023-02-15        70.0
# 13                                    Amapiano   2023-05-23        70.0
# 14                           Party No Dey Stop   2023-03-14        69.0
# 15                                    Sability   2023-02-10        69.0
# 16                                      Unruly   2023-08-08        69.0
# 17                                       Enjoy   2023-07-14        64.0
# 18                                        Mumu   2023-10-11        64.0
# 19                          Shu! (feat. Chley)   2023-07-03        63.0
